# %%
#Extract wkt text from NMEP city shape files
# Warri, Minna, Osogbo and Zaria hvae errors in their wkt. Tried reprojecting crs, did not work

# %%
import fiona
from shapely.geometry import shape
import geopandas as gpd
from shapely.ops import unary_union

# %%
# Warri
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Warri/Warri.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs= 4326)

print(combined_polygon)

# %%
##WARRI AGAIN
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Warri/Warri.shp'
gdf = gpd.read_file(shapefile_path)

gdf = gdf.to_crs(epsg=4326)
combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs='EPSG:4326')

print(combined_polygon)

# %%
#Asaba
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Asaba/Asaba.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=gdf.crs)

print(combined_polygon)

# %%
# DELTA STATE
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/NMEP Net Distribution States Shapefiles for ADM3 - 13 States/Delta/Delta_Wards.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=gdf.crs)

print(combined_polygon)

# %%
#Abeokuta
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Abeokuta/Abeokuta.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=gdf.crs)

print(combined_polygon)

# %%
#Damaturu
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Damaturu/Damaturu.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=gdf.crs)

print(combined_polygon)

# %%
#Dutse
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Dutse/Dutse.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=gdf.crs)

print(combined_polygon)

# %%
#Gombe
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Gombe/Gombe.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=gdf.crs)

print(combined_polygon)
# Out:
# MULTIPOLYGON (((11.190288769000064 10.27083667300006, 11.189963576000027 10.269908684000017, 11.187930827000061 10.269156951000067, 11.186551002000046 10.26879148000005, 11.185724119000042 10.268762078000064, 11.185014297000068 10.269004488000052, 11.183895950000025 10.268481007000041, 11.18269446900007 10.267008286000005, 11.182646755000064 10.266410298000023, 11.182046010000025 10.266061532000029, 11.181439711000055 10.265976582000071, 11.180846851000073 10.266542839000072, 11.18003791800004 10.26666777000001, 11.179303205000057 10.266236794000056, 11.178851493000025 10.265863601000017, 11.178746455000068 10.265470519000061, 11.179041838000048 10.265031221000072, 11.179089439000053 10.264792842000075, 11.178624223000046 10.264636038000042, 11.177797078000026 10.264616399000019, 11.177455932000044 10.264610590000064, 11.177210675000028 10.264406679000032, 11.177075271000039 10.264191672000027, 11.177083655000049 10.26367538700002, 11.176701535000065 10.263587518000055, 11.1762503810
# ...

# %%
#Ilorin
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Ilorin/Ilorin.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=gdf.crs)

print(combined_polygon)

# %%
#Jalingo
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Jalingo/Jalingo.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=gdf.crs)

print(combined_polygon)

# %%
#Kano
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Kano/Kano.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=gdf.crs)

print(combined_polygon)

# %%
#Katsina
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Katsina/Katsina.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=gdf.crs)

print(combined_polygon)

# %%
#Minna
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Minna/Minna.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=gdf.crs)

print(combined_polygon)

# %%
#Osogbo
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Osogbo/Osogbo.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs=4326)

print(combined_polygon)

# %%
#Zaria
shapefile_path = 'C:/Users/USER/Urban Malaria Proj Dropbox/urban_malaria/data/nigeria/shapefiles/ShinyApp_shapefiles/Zaria/Zaria.shp'
gdf = gpd.read_file(shapefile_path)

combined_polygon = unary_union(gdf['geometry'])
combined_gdf = gpd.GeoDataFrame([1], geometry=[combined_polygon], crs= 4326)

print(combined_polygon)
